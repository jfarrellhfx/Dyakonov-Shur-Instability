# %% [markdown]
# Author: Jack Farrell

# %% [markdown]
# # Preliminary
#
# This notebook tries to reproduce the results of Fig. 2 in Mendl et al. 2019.  They claim that hydrodynamic electrons satisfying certain boundary conditions act as a nonlinear oscillator in the Terahertz range.
#
# ## Equations
# The equations are the isothermal equations of gas dynamics, with a couple extra terms that I put on the RHS.  In their non-dimensional form, they look like:
#
# $$\partial_t J + \partial_x \left(n + \frac{J^2}{n} \right) = \eta \partial^2_x \left(\frac{J}{n}\right) + \gamma (n v_0 - J),$$
#
# $$\partial_t n + \partial_x J = 0.$$
#
# So they are the Navier-Stokes equation and the continuity equation.  The term $\partial_xn$ in the Navier-Stokes equation comes from assuming a simple form for the pressure.  The weird boundary conditions are:
#
# $$n(0) = 1,$$
# $$\partial_xJ(0) = 0,$$
# $$J(1) = v_0.$$
#
# We choose dimensionless parameters $\eta = 0.02$, $\gamma = 0.04$, $v_0 = 0.14$.
#
# ## Numerical Method
# ### Conservation Law
# If you forget about the terms on the RHS of the Navier-Stokes equation, we can write the remaining stuff as a *vector conservation law*.  A conservation law has the form: $\partial_t \vec{u} + \partial_x \vec{f}(\vec{u}) = 0$, where $\vec{u}$ is a state vector and $\vec{f}$ is the "flux vector".  In our case, the conservation law is is:
# $$\partial_t \begin{pmatrix}n \\ J \end{pmatrix} + \partial_x \begin{pmatrix} J \\ \frac{J^2}{n} + n\end{pmatrix} = 0.$$
# Conservation laws are handled well by finite volume methods, so we'll use one of those.  But we have to still deal with the other stuff that is not part of the conservation law. For the dissipative term with $\eta$, we'll directly incorporate it in the time-stepping as a finite differences quotient.  For the relaxation term with $\gamma$, we'll employ an approach called "operator splitting", specifically, "Strang Splitting".
#
# #### Slope Limiting
# The conservation law step uses a high resolution method that approximates the function as piecewise - linear.  This means we have to pick the slopes somehow - this code implements two "slope-limiting" techniques: One is "minmod" which is the most diffusive one, and the other is "superbee", which should be a little bit sharper [3].
#
# ### Relaxation Step
# Pretend the Navier-Stokes equation only has the term with $\gamma$.  Then it's an ODE that reads:
#
# $$\partial_t J = \gamma(nv_0-J).$$
#
# You can solve this one exactly, and the answer is $J(t) = nv_0 + (J_0 - nv_0)e^{-\gamma t}$.  So this step we can perform exactly, just setting $J_0$ as the value one time step in the past!
#
#
# # Simulation

# %%
#Imports
import numpy as np
import matplotlib.pyplot as plt
from scipy import linalg

# %%
#Settings
imageLog = False #during the simulation, will plot a graph every 1.0 sec of sim time so you can check on it
saveFigures = True #If true, will save pdfs of all figures

# %%
#Global things
eps = np.finfo(float).eps #machine epsilon
k = 0.001 #Time Step
h = 1/50. #Mesh width
T = 152.0 #stopping time

# %%
#Define Helper Functions
def minmod(a,b):
    """
    The minmod function gives a simple way of doing slope-limiting (used in the high resolution correction)
    """
    if np.abs(a) < np.abs(b) and a * b > 0:
        return a
    elif np.abs(b) < np.abs(a) and a * b > 0:
        return b
    else:
        return 0
    
def maxmod(a,b):
    """
    Helper function for superbee limiter
    """
    if np.abs(a) > np.abs(b) and a * b > 0:
        return a
    elif np.abs(b) > np.abs(a) and a * b > 0:
        return b
    else:
        return 0

def superbee(a,b):
    """
    A less diffusive slope-limiter
    """
    s1 = minmod(b, 2*a)
    s2 = minmod(2 * b, a)
    
    return maxmod(s1, s2)

#Select which slope-limiter
slopeLimiter = minmod 

def eigenExpand(uleft, uright):
    """
    Expands jump in state vector from cell to cell in terms of
    the eigenfunctions of the Roe matrix 'A' which is hard
    coded in.  uL and uR should be two-component state vectors, 
    i.e., numpy arrays with 2 components.
    """
    nleft, Jleft = uleft
    nright, Jright = uright
    jump_in = uright - uleft
    v_in =(nleft**0.5*Jleft/(nleft) + nright**0.5*Jleft/(nright))/(nleft**0.5 + nright**0.5)
    #Want to solve for "alpha1, alpha2", the coefficients of each eigenvector
    #in the expansion of the jump.  We do that here!
    alpha1_in = (jump_in[0] * (v_in + 1) - jump_in[1])/2
    alpha2_in = (-jump_in[0] * (v_in - 1) + jump_in[1])/2
    
    return alpha1_in, alpha2_in

def f(u):
    """
    flux term in equation.  In our case, the it is a vector [J, J**2/n + n].
    Just a convenience function that does this calcul
    """
    n_in, J_in = u
    return np.array([J_in,J_in**2/n_in + n_in])

def flux(uL, uR, UL, UR):
    """
    Finite volume methods approximate the average of the solution on a bunch of
    cells.  The averages are updated by the "flux" through the boundaries of the
    cell.  This function computes the flux at the boundary between uL and uR.  
    Because of the high resolution method used, the values at one previous cell,
    UL and UR are also needed.
    """
    nL, JL = uL
    nR, JR = uR
    jump = uR - uL
    #rho averaged velocity
    v = (nL**0.5*JL/(nL+eps) + nR**0.5*JR/(nR))/(nL**0.5 + nR**0.5)
    #Hard-code eigenvectors and eigenvalues (from [3])
    r1 = [1, v - 1]
    w1 = v - 1
    r2 = [1, v + 1]
    w2 = v + 1
    alpha1, alpha2 = eigenExpand(uL, uR)
    
    #Get the gobunov flux
    fG = f(uL) + min(w1, 0) *  alpha1 * np.array(r1) + min(w2, 0) * alpha2 * np.array(r2)
    
    #For next part, need the "j - 1" value of the alpha1, alpha2 expansion
    #coefficients.  I give these new variable names by switching the case
    #of everything
    NL, jL = UL
    NR, jR = UR
    Jump = UR - UL
    V = (NL**0.5*jL/NL + NR**0.5*jR/NR)/(NL**0.5 + NR**0.5)
    R1 = [1, V - 1]
    W1 = V - 1
    R2 = [1, V + 1]
    W2 = V + 1
    Alpha1, Alpha2 = eigenExpand(UL, UR)
    
    #Here's the slope limiting thing
    sigma1 = 1/h*np.array(
    [slopeLimiter(alpha1 * r1[0], Alpha1 * R1[0]), slopeLimiter(alpha1 * r1[1], Alpha1 * R1[1])])
    
    sigma2 = 1/h*np.array(
    [slopeLimiter(alpha2 * r2[0], Alpha2 * R2[0]), slopeLimiter(alpha2 * r2[1], Alpha2 * R2[1])])
    
    #The high resolution correction to the flux:
    additionalFlux = 1/2 * (w1 * (np.sign(k * w1 / h) - k * w1 / h) * h * sigma1 + w2 * (np.sign(k * w2 / h) - k * w2 / h) * h * sigma2)
    
    F = fG + additionalFlux
    
    return F

# %%
#Set up the domain of the problem in space and time.
x = np.arange(0., 1.0, h)
tau = np.arange(0., T, k)

#like to do computations at midpoints for finite volume methods
xMid = x[:-1] + h / 2

#Parameters
v0 = 0.14 #dimensionless velocity
eta = 0.01 #dimensionless viscosity
gamma = 0.04 #dimensionless momentum relaxation rate

n0 = 1. + 0.1 * np.sin(xMid*np.pi)
J0 = v0 * (1. + 0.2 * np.cos(np.pi * xMid / 2))

u = np.vstack((n0, J0)).T

#Storage
J_list = []
n_list = []

J_list.append(np.copy(u[:,1]))
n_list.append(np.copy(u[:,0]))
N = 0

for t in np.arange(0, T, k):
     #First part of the Strang Splitting - integrate the relaxation term up to
    #dt / 2
    
        
    #Now impose boundary conditions on left and right!
    uLeft = np.array([[1.,u[2][1]], [1.,u[1][1]]])
    uRight = np.array([[2*u[-1][0] - u[-2][0], v0], [u[-1,0], v0]])
    u[:,1] = u[:,0] * v0 + (u[:,1] - u[:,0] * v0) * np.exp(-gamma * k / 2)
                     
    uBC = np.vstack((uLeft, u, uRight))
    U = np.copy(u)
    #the uBC array has the real physical domain and also some extra "ghost" cells used to
    #do the boundary conditions.
    n = uBC[:,0] #just useful
    J = uBC[:,1]
    q = J / n

    for j in range(2, uBC.shape[0] - 2): #iterate through the *physical* domain
        #Call the flux() function at the left and right boundary of each cell
        FMinus = flux(uBC[j - 1], uBC[j], uBC[j - 2], uBC[j - 1])
        FPlus = flux(uBC[j], uBC[j + 1], uBC[j - 1], uBC[j])
        
        #Approximate the dissipative term by a finite differences quotient (2nd order)
        dissipative = k * np.array([0, eta * 1/h**2 * (q[j + 1] - 2 * q[j] + q[j - 1])])
        
    
        #Update each element of physical domain
        U[j-2] = u[j-2] - k / h * (FPlus - FMinus) + dissipative # + 0.0075 * k * 1/h**2 * (uBC[j + 1] - 2*uBC[j] + uBC[j - 1])
        #Note the last term in the above is the-made up viscous term!
        
    #Second step of Strang Splitting, same integration
    U[:,1] = U[:,0] * v0 + (U[:,1] - U[:,0] * v0) * np.exp(-gamma * k / 2)

    #send to the storage lists
    J_list.append(np.copy(U[:,1]))
    n_list.append(np.copy(U[:,0]))
    u = np.copy(U)
    
    #Log Progress
    if N % 500 == 0:
        print("Time is {:.3f} out of {:.3f} - - - - Iteration {}".format(t, T, N))
    if N % 1000 == 0 and imageLog:
        fig, axes = plt.subplots(1,2)
        ax1, ax2 = axes
        ax1.plot([list[-1] for list in n_list])
        ax1.set_title("n(L,t)")
        ax2.plot(J_list[-1])
        ax2.set_title("J")
        plt.show()
    N += 1
# Out:
# Time is 0.000 out of 152.000 - - - - Iteration 0
# Time is 0.500 out of 152.000 - - - - Iteration 500
# Time is 1.000 out of 152.000 - - - - Iteration 1000
# Time is 1.500 out of 152.000 - - - - Iteration 1500
# Time is 2.000 out of 152.000 - - - - Iteration 2000
# Time is 2.500 out of 152.000 - - - - Iteration 2500
# Time is 3.000 out of 152.000 - - - - Iteration 3000
# Time is 3.500 out of 152.000 - - - - Iteration 3500
# Time is 4.000 out of 152.000 - - - - Iteration 4000
# Time is 4.500 out of 152.000 - - - - Iteration 4500
# Time is 5.000 out of 152.000 - - - - Iteration 5000
# Time is 5.500 out of 152.000 - - - - Iteration 5500
# Time is 6.000 out of 152.000 - - - - Iteration 6000
# Time is 6.500 out of 152.000 - - - - Iteration 6500
# Time is 7.000 out of 152.000 - - - - Iteration 7000
# Time is 7.500 out of 152.000 - - - - Iteration 7500
# Time is 8.000 out of 152.000 - - - - Iteration 8000
# Time is 8.500 out of 152.000 - - - - Iteration 8500
# Time is 9.000 out of 152.000 - - - - Iteration 9000
# Time is 9.500 out of 152.000 - - - - Iteration 9500
# Time is 10.000 out of 152.000 - - - - Iteration 10000
# Time is 10.500 out of 152.000 - - - - Iteration 10500
# Time is 11.000 out of 152.000 - - - - Iteration 11000
# Time is 11.500 out of 152.000 - - - - Iteration 11500
# Time is 12.000 out of 152.000 - - - - Iteration 12000
# Time is 12.500 out of 152.000 - - - - Iteration 12500
# Time is 13.000 out of 152.000 - - - - Iteration 13000
# Time is 13.500 out of 152.000 - - - - Iteration 13500
# Time is 14.000 out of 152.000 - - - - Iteration 14000
# Time is 14.500 out of 152.000 - - - - Iteration 14500
# Time is 15.000 out of 152.000 - - - - Iteration 15000
# Time is 15.500 out of 152.000 - - - - Iteration 15500
# Time is 16.000 out of 152.000 - - - - Iteration 16000
# Time is 16.500 out of 152.000 - - - - Iteration 16500
# Time is 17.000 out of 152.000 - - - - Iteration 17000
# Time is 17.500 out of 152.000 - - - - Iteration 17500
# Time is 18.000 out of 152.000 - - - - Iteration 18000
# Time is 18.500 out of 152.000 - - - - Iteration 18500
# Time is 19.000 out of 152.000 - - - - Iteration 19000
# Time is 19.500 out of 152.000 - - - - Iteration 19500
# Time is 20.000 out of 152.000 - - - - Iteration 20000
# Time is 20.500 out of 152.000 - - - - Iteration 20500
# Time is 21.000 out of 152.000 - - - - Iteration 21000
# Time is 21.500 out of 152.000 - - - - Iteration 21500
# Time is 22.000 out of 152.000 - - - - Iteration 22000
# Time is 22.500 out of 152.000 - - - - Iteration 22500
# Time is 23.000 out of 152.000 - - - - Iteration 23000
# Time is 23.500 out of 152.000 - - - - Iteration 23500
# Time is 24.000 out of 152.000 - - - - Iteration 24000
# Time is 24.500 out of 152.000 - - - - Iteration 24500
# Time is 25.000 out of 152.000 - - - - Iteration 25000
# Time is 25.500 out of 152.000 - - - - Iteration 25500
# Time is 26.000 out of 152.000 - - - - Iteration 26000
# Time is 26.500 out of 152.000 - - - - Iteration 26500
# Time is 27.000 out of 152.000 - - - - Iteration 27000
# Time is 27.500 out of 152.000 - - - - Iteration 27500
# Time is 28.000 out of 152.000 - - - - Iteration 28000
# Time is 28.500 out of 152.000 - - - - Iteration 28500
# Time is 29.000 out of 152.000 - - - - Iteration 29000
# Time is 29.500 out of 152.000 - - - - Iteration 29500
# Time is 30.000 out of 152.000 - - - - Iteration 30000
# Time is 30.500 out of 152.000 - - - - Iteration 30500
# Time is 31.000 out of 152.000 - - - - Iteration 31000
# Time is 31.500 out of 152.000 - - - - Iteration 31500
# Time is 32.000 out of 152.000 - - - - Iteration 32000
# Time is 32.500 out of 152.000 - - - - Iteration 32500
# Time is 33.000 out of 152.000 - - - - Iteration 33000
# Time is 33.500 out of 152.000 - - - - Iteration 33500
# Time is 34.000 out of 152.000 - - - - Iteration 34000
# Time is 34.500 out of 152.000 - - - - Iteration 34500
# Time is 35.000 out of 152.000 - - - - Iteration 35000
# Time is 35.500 out of 152.000 - - - - Iteration 35500
# Time is 36.000 out of 152.000 - - - - Iteration 36000
# Time is 36.500 out of 152.000 - - - - Iteration 36500
# Time is 37.000 out of 152.000 - - - - Iteration 37000
# Time is 37.500 out of 152.000 - - - - Iteration 37500
# Time is 38.000 out of 152.000 - - - - Iteration 38000
# Time is 38.500 out of 152.000 - - - - Iteration 38500
# Time is 39.000 out of 152.000 - - - - Iteration 39000
# Time is 39.500 out of 152.000 - - - - Iteration 39500
# Time is 40.000 out of 152.000 - - - - Iteration 40000
# Time is 40.500 out of 152.000 - - - - Iteration 40500
# Time is 41.000 out of 152.000 - - - - Iteration 41000
# Time is 41.500 out of 152.000 - - - - Iteration 41500
# Time is 42.000 out of 152.000 - - - - Iteration 42000
# Time is 42.500 out of 152.000 - - - - Iteration 42500
# Time is 43.000 out of 152.000 - - - - Iteration 43000
# Time is 43.500 out of 152.000 - - - - Iteration 43500
# Time is 44.000 out of 152.000 - - - - Iteration 44000
# Time is 44.500 out of 152.000 - - - - Iteration 44500
# Time is 45.000 out of 152.000 - - - - Iteration 45000
# Time is 45.500 out of 152.000 - - - - Iteration 45500
# Time is 46.000 out of 152.000 - - - - Iteration 46000
# Time is 46.500 out of 152.000 - - - - Iteration 46500
# Time is 47.000 out of 152.000 - - - - Iteration 47000
# Time is 47.500 out of 152.000 - - - - Iteration 47500
# Time is 48.000 out of 152.000 - - - - Iteration 48000
# Time is 48.500 out of 152.000 - - - - Iteration 48500
# Time is 49.000 out of 152.000 - - - - Iteration 49000
# Time is 49.500 out of 152.000 - - - - Iteration 49500
# Time is 50.000 out of 152.000 - - - - Iteration 50000
# Time is 50.500 out of 152.000 - - - - Iteration 50500
# Time is 51.000 out of 152.000 - - - - Iteration 51000
# Time is 51.500 out of 152.000 - - - - Iteration 51500
# Time is 52.000 out of 152.000 - - - - Iteration 52000
# Time is 52.500 out of 152.000 - - - - Iteration 52500
# Time is 53.000 out of 152.000 - - - - Iteration 53000
# Time is 53.500 out of 152.000 - - - - Iteration 53500
# Time is 54.000 out of 152.000 - - - - Iteration 54000
# Time is 54.500 out of 152.000 - - - - Iteration 54500
# Time is 55.000 out of 152.000 - - - - Iteration 55000
# Time is 55.500 out of 152.000 - - - - Iteration 55500
# Time is 56.000 out of 152.000 - - - - Iteration 56000
# Time is 56.500 out of 152.000 - - - - Iteration 56500
# Time is 57.000 out of 152.000 - - - - Iteration 57000
# Time is 57.500 out of 152.000 - - - - Iteration 57500
# Time is 58.000 out of 152.000 - - - - Iteration 58000
# Time is 58.500 out of 152.000 - - - - Iteration 58500
# Time is 59.000 out of 152.000 - - - - Iteration 59000
# Time is 59.500 out of 152.000 - - - - Iteration 59500
# Time is 60.000 out of 152.000 - - - - Iteration 60000
# Time is 60.500 out of 152.000 - - - - Iteration 60500
# Time is 61.000 out of 152.000 - - - - Iteration 61000
# Time is 61.500 out of 152.000 - - - - Iteration 61500
# Time is 62.000 out of 152.000 - - - - Iteration 62000
# Time is 62.500 out of 152.000 - - - - Iteration 62500
# Time is 63.000 out of 152.000 - - - - Iteration 63000
# Time is 63.500 out of 152.000 - - - - Iteration 63500
# Time is 64.000 out of 152.000 - - - - Iteration 64000
# Time is 64.500 out of 152.000 - - - - Iteration 64500
# Time is 65.000 out of 152.000 - - - - Iteration 65000
# Time is 65.500 out of 152.000 - - - - Iteration 65500
# Time is 66.000 out of 152.000 - - - - Iteration 66000
# Time is 66.500 out of 152.000 - - - - Iteration 66500
# Time is 67.000 out of 152.000 - - - - Iteration 67000
# Time is 67.500 out of 152.000 - - - - Iteration 67500
# Time is 68.000 out of 152.000 - - - - Iteration 68000
# Time is 68.500 out of 152.000 - - - - Iteration 68500
# Time is 69.000 out of 152.000 - - - - Iteration 69000
# Time is 69.500 out of 152.000 - - - - Iteration 69500
# Time is 70.000 out of 152.000 - - - - Iteration 70000
# Time is 70.500 out of 152.000 - - - - Iteration 70500
# Time is 71.000 out of 152.000 - - - - Iteration 71000
# Time is 71.500 out of 152.000 - - - - Iteration 71500
# Time is 72.000 out of 152.000 - - - - Iteration 72000
# Time is 72.500 out of 152.000 - - - - Iteration 72500
# Time is 73.000 out of 152.000 - - - - Iteration 73000
# Time is 73.500 out of 152.000 - - - - Iteration 73500
# Time is 74.000 out of 152.000 - - - - Iteration 74000
# Time is 74.500 out of 152.000 - - - - Iteration 74500
# Time is 75.000 out of 152.000 - - - - Iteration 75000
# Time is 75.500 out of 152.000 - - - - Iteration 75500
# Time is 76.000 out of 152.000 - - - - Iteration 76000
# Time is 76.500 out of 152.000 - - - - Iteration 76500
# Time is 77.000 out of 152.000 - - - - Iteration 77000
# Time is 77.500 out of 152.000 - - - - Iteration 77500
# Time is 78.000 out of 152.000 - - - - Iteration 78000
# Time is 78.500 out of 152.000 - - - - Iteration 78500
# Time is 79.000 out of 152.000 - - - - Iteration 79000
# Time is 79.500 out of 152.000 - - - - Iteration 79500
# Time is 80.000 out of 152.000 - - - - Iteration 80000
# Time is 80.500 out of 152.000 - - - - Iteration 80500
# Time is 81.000 out of 152.000 - - - - Iteration 81000
# Time is 81.500 out of 152.000 - - - - Iteration 81500
# Time is 82.000 out of 152.000 - - - - Iteration 82000
# Time is 82.500 out of 152.000 - - - - Iteration 82500
# Time is 83.000 out of 152.000 - - - - Iteration 83000
# Time is 83.500 out of 152.000 - - - - Iteration 83500
# Time is 84.000 out of 152.000 - - - - Iteration 84000
# Time is 84.500 out of 152.000 - - - - Iteration 84500
# Time is 85.000 out of 152.000 - - - - Iteration 85000
# Time is 85.500 out of 152.000 - - - - Iteration 85500
# Time is 86.000 out of 152.000 - - - - Iteration 86000
# Time is 86.500 out of 152.000 - - - - Iteration 86500
# Time is 87.000 out of 152.000 - - - - Iteration 87000
# Time is 87.500 out of 152.000 - - - - Iteration 87500
# Time is 88.000 out of 152.000 - - - - Iteration 88000
# Time is 88.500 out of 152.000 - - - - Iteration 88500
# Time is 89.000 out of 152.000 - - - - Iteration 89000
# Time is 89.500 out of 152.000 - - - - Iteration 89500
# Time is 90.000 out of 152.000 - - - - Iteration 90000
# Time is 90.500 out of 152.000 - - - - Iteration 90500
# Time is 91.000 out of 152.000 - - - - Iteration 91000
# Time is 91.500 out of 152.000 - - - - Iteration 91500
# Time is 92.000 out of 152.000 - - - - Iteration 92000
# Time is 92.500 out of 152.000 - - - - Iteration 92500
# Time is 93.000 out of 152.000 - - - - Iteration 93000
# Time is 93.500 out of 152.000 - - - - Iteration 93500
# Time is 94.000 out of 152.000 - - - - Iteration 94000
# Time is 94.500 out of 152.000 - - - - Iteration 94500
# Time is 95.000 out of 152.000 - - - - Iteration 95000
# Time is 95.500 out of 152.000 - - - - Iteration 95500
# Time is 96.000 out of 152.000 - - - - Iteration 96000
# Time is 96.500 out of 152.000 - - - - Iteration 96500
# Time is 97.000 out of 152.000 - - - - Iteration 97000
# Time is 97.500 out of 152.000 - - - - Iteration 97500
# Time is 98.000 out of 152.000 - - - - Iteration 98000
# Time is 98.500 out of 152.000 - - - - Iteration 98500
# Time is 99.000 out of 152.000 - - - - Iteration 99000
# Time is 99.500 out of 152.000 - - - - Iteration 99500
# Time is 100.000 out of 152.000 - - - - Iteration 100000
# Time is 100.500 out of 152.000 - - - - Iteration 100500
# Time is 101.000 out of 152.000 - - - - Iteration 101000
# Time is 101.500 out of 152.000 - - - - Iteration 101500
# Time is 102.000 out of 152.000 - - - - Iteration 102000
# Time is 102.500 out of 152.000 - - - - Iteration 102500
# Time is 103.000 out of 152.000 - - - - Iteration 103000
# Time is 103.500 out of 152.000 - - - - Iteration 103500
# Time is 104.000 out of 152.000 - - - - Iteration 104000
# Time is 104.500 out of 152.000 - - - - Iteration 104500
# Time is 105.000 out of 152.000 - - - - Iteration 105000
# Time is 105.500 out of 152.000 - - - - Iteration 105500
# Time is 106.000 out of 152.000 - - - - Iteration 106000
# Time is 106.500 out of 152.000 - - - - Iteration 106500
# Time is 107.000 out of 152.000 - - - - Iteration 107000
# Time is 107.500 out of 152.000 - - - - Iteration 107500
# Time is 108.000 out of 152.000 - - - - Iteration 108000
# Time is 108.500 out of 152.000 - - - - Iteration 108500
# Time is 109.000 out of 152.000 - - - - Iteration 109000
# Time is 109.500 out of 152.000 - - - - Iteration 109500
# Time is 110.000 out of 152.000 - - - - Iteration 110000
# Time is 110.500 out of 152.000 - - - - Iteration 110500
# Time is 111.000 out of 152.000 - - - - Iteration 111000
# Time is 111.500 out of 152.000 - - - - Iteration 111500
# Time is 112.000 out of 152.000 - - - - Iteration 112000
# Time is 112.500 out of 152.000 - - - - Iteration 112500
# Time is 113.000 out of 152.000 - - - - Iteration 113000
# Time is 113.500 out of 152.000 - - - - Iteration 113500
# Time is 114.000 out of 152.000 - - - - Iteration 114000
# Time is 114.500 out of 152.000 - - - - Iteration 114500
# Time is 115.000 out of 152.000 - - - - Iteration 115000
# Time is 115.500 out of 152.000 - - - - Iteration 115500
# Time is 116.000 out of 152.000 - - - - Iteration 116000
# Time is 116.500 out of 152.000 - - - - Iteration 116500
# Time is 117.000 out of 152.000 - - - - Iteration 117000
# Time is 117.500 out of 152.000 - - - - Iteration 117500
# Time is 118.000 out of 152.000 - - - - Iteration 118000
# Time is 118.500 out of 152.000 - - - - Iteration 118500
# Time is 119.000 out of 152.000 - - - - Iteration 119000
# Time is 119.500 out of 152.000 - - - - Iteration 119500
# Time is 120.000 out of 152.000 - - - - Iteration 120000
# Time is 120.500 out of 152.000 - - - - Iteration 120500
# Time is 121.000 out of 152.000 - - - - Iteration 121000
# Time is 121.500 out of 152.000 - - - - Iteration 121500
# Time is 122.000 out of 152.000 - - - - Iteration 122000
# Time is 122.500 out of 152.000 - - - - Iteration 122500
# Time is 123.000 out of 152.000 - - - - Iteration 123000
# Time is 123.500 out of 152.000 - - - - Iteration 123500
# Time is 124.000 out of 152.000 - - - - Iteration 124000
# Time is 124.500 out of 152.000 - - - - Iteration 124500
# Time is 125.000 out of 152.000 - - - - Iteration 125000
# Time is 125.500 out of 152.000 - - - - Iteration 125500
# Time is 126.000 out of 152.000 - - - - Iteration 126000
# Time is 126.500 out of 152.000 - - - - Iteration 126500
# Time is 127.000 out of 152.000 - - - - Iteration 127000
# Time is 127.500 out of 152.000 - - - - Iteration 127500
# Time is 128.000 out of 152.000 - - - - Iteration 128000
# Time is 128.500 out of 152.000 - - - - Iteration 128500
# Time is 129.000 out of 152.000 - - - - Iteration 129000
# Time is 129.500 out of 152.000 - - - - Iteration 129500
# Time is 130.000 out of 152.000 - - - - Iteration 130000
# Time is 130.500 out of 152.000 - - - - Iteration 130500
# Time is 131.000 out of 152.000 - - - - Iteration 131000
# Time is 131.500 out of 152.000 - - - - Iteration 131500
# Time is 132.000 out of 152.000 - - - - Iteration 132000
# Time is 132.500 out of 152.000 - - - - Iteration 132500
# Time is 133.000 out of 152.000 - - - - Iteration 133000
# Time is 133.500 out of 152.000 - - - - Iteration 133500
# Time is 134.000 out of 152.000 - - - - Iteration 134000
# Time is 134.500 out of 152.000 - - - - Iteration 134500
# Time is 135.000 out of 152.000 - - - - Iteration 135000
# Time is 135.500 out of 152.000 - - - - Iteration 135500
# Time is 136.000 out of 152.000 - - - - Iteration 136000
# Time is 136.500 out of 152.000 - - - - Iteration 136500
# Time is 137.000 out of 152.000 - - - - Iteration 137000
# Time is 137.500 out of 152.000 - - - - Iteration 137500
# Time is 138.000 out of 152.000 - - - - Iteration 138000
# Time is 138.500 out of 152.000 - - - - Iteration 138500
# Time is 139.000 out of 152.000 - - - - Iteration 139000
# Time is 139.500 out of 152.000 - - - - Iteration 139500
# Time is 140.000 out of 152.000 - - - - Iteration 140000
# Time is 140.500 out of 152.000 - - - - Iteration 140500
# Time is 141.000 out of 152.000 - - - - Iteration 141000
# Time is 141.500 out of 152.000 - - - - Iteration 141500
# Time is 142.000 out of 152.000 - - - - Iteration 142000
# Time is 142.500 out of 152.000 - - - - Iteration 142500
# Time is 143.000 out of 152.000 - - - - Iteration 143000
# Time is 143.500 out of 152.000 - - - - Iteration 143500
# Time is 144.000 out of 152.000 - - - - Iteration 144000
# Time is 144.500 out of 152.000 - - - - Iteration 144500
# Time is 145.000 out of 152.000 - - - - Iteration 145000
# Time is 145.500 out of 152.000 - - - - Iteration 145500
# Time is 146.000 out of 152.000 - - - - Iteration 146000
# Time is 146.500 out of 152.000 - - - - Iteration 146500
# Time is 147.000 out of 152.000 - - - - Iteration 147000
# Time is 147.500 out of 152.000 - - - - Iteration 147500
# Time is 148.000 out of 152.000 - - - - Iteration 148000
# Time is 148.500 out of 152.000 - - - - Iteration 148500
# Time is 149.000 out of 152.000 - - - - Iteration 149000
# Time is 149.500 out of 152.000 - - - - Iteration 149500
# Time is 150.000 out of 152.000 - - - - Iteration 150000
# Time is 150.500 out of 152.000 - - - - Iteration 150500
# Time is 151.000 out of 152.000 - - - - Iteration 151000
# Time is 151.500 out of 152.000 - - - - Iteration 151500

# %% [markdown]
# # Results

# %%
#Figures
from matplotlib import rc
import matplotlib.ticker as tckr
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('png', 'pdf')

#Matplotlib Parameters
plt.rc('text', usetex=True)
plt.rc('font', family='serif', size=12)

#Mendl et al. Fig. 2
fig2, axes2 = plt.subplots(1,1, figsize = (4,4))
ax21 = axes2
ax21.grid()
ax21.plot(tau[:int(80./k)], [list[-1] for list in n_list][:int(80./k)],lw = 1, color = "Black")
ax21.set_xlabel("$v_s t / L$")
ax21.set_ylabel("$n(L,t)/n_0$")
fig2.tight_layout()
if saveFigures:
    plt.savefig("Figures/resonance_minmod.pdf")
plt.show()

#Mendl et. al Fig. 3 (Used different time for snapshots b.c. I only ran 80.0 seconds of sim time)
fig3, axes3 = plt.subplots(2, 5, figsize = (10,5), sharex = True, sharey = True)
J_snapshots = []
n_snapshots = []
delta = 0.5 #time difference between snapshots in seconds
start = 147. #time to start snapshots in seconds
for number in range(10):
    index = int((start + delta * number) / k)
    J_snapshots.append(J_list[index])
    n_snapshots.append(n_list[index])
index = 0
for i in axes3:
    for axis in i:
        axis.grid()
        axis.plot(xMid, n_snapshots[index], label = "$n/n_0$")
        axis.plot(xMid, J_snapshots[index], label = "$J/n_0v_s$")
        axis.set_title("$v_st/L = {:.1f}$".format(start + delta * index))
        index += 1
for axis in axes3[-1]:
    axis.set_xlabel("$x/L$") #Set label only on the bottom axes
axes3[0,0].legend()
fig3.tight_layout()
if saveFigures:
    plt.savefig("Figures/snapshots_minmod.pdf")
plt.show()

# %% [markdown]
# # References

# %% [markdown]
# 1. Mendl, C. B., Polini, M., & Lucas, A. (2019). Coherent Terahertz Radiation from a Nonlinear Oscillator of Viscous Electrons. Retrieved from http://arxiv.org/abs/1909.11093
# 2. LeVeque, R. (2002). Finite Volume Methods for Hyperbolic Problems (Cambridge Texts in Applied Mathematics). Cambridge: Cambridge University Press. doi:10.1017/CBO9780511791253
# 3. LeVeque, R. J. (1992). Numerical methods for conservation laws. Basel: Birkhäuser. doi: DOI https://doi.org/10.1007/978-3- 0348-8629-1
